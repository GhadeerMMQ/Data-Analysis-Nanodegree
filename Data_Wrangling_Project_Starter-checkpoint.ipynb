# %% [markdown]
# # Real-world Data Wrangling

# %% [markdown]
# In this project, you will apply the skills you acquired in the course to gather and wrangle real-world data with two datasets of your choice.
#
# You will retrieve and extract the data, assess the data programmatically and visually, accross elements of data quality and structure, and implement a cleaning strategy for the data. You will then store the updated data into your selected database/data store, combine the data, and answer a research question with the datasets.
#
# Throughout the process, you are expected to:
#
# 1. Explain your decisions towards methods used for gathering, assessing, cleaning, storing, and answering the research question
# 2. Write code comments so your code is more readable
#
# Before you start, install the some of the required packages.

# %%
# !python -m pip install kaggle==1.6.12

# %%
import pandas as pd
import requests
import time
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
pip install python-dotenv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import configparser

config = configparser.ConfigParser()
config.read("config.ini")

api_key = config["api"]["key"]
print(api_key[:4] + "****")
# Out:
# 08d1****

# %%
import os
print(os.getcwd())

import configparser
config = configparser.ConfigParser()
print(config.read("config.ini"))
print(config.sections())
# Out:
# d:\corpo\second project\.ipynb_checkpoints\notebooks
# ['config.ini']
# ['api']

# %% [markdown]
# ## 1. Gather data

# %% [markdown]
# ### **1.1.** Problem Statement
# Which movie genres on Netflix tend to have higher TMDB ratings, and how does popularity relate to these ratings?

# %% [markdown]
# ### **1.2.** Gather at least two datasets using two different data gathering methods

# %% [markdown]
# #### **Dataset 1**
# Type: CSV File
#
# Method: The data was gathered using the "Downloading files" method from https://www.kaggle.com/datasets/shivamb/netflix-shows
#
# Dataset variables:
# show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in,  description

# %%
neetflix_titles_raw=pd.read_csv("D:\corpo\DFOnetflix_titles.csv")
neetflix_titles_raw.info()
display(neetflix_titles_raw.tail(20))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB
#      show_id     type                          title                 director  \
# 8787   s8788    Movie      You Can’t Fight Christmas              Kenny Young
# ...

# %% [markdown]
# #### Dataset 2
#
# Type: API
#
# Method: The data was gathered using the "API" method from The movie database TMDb.
#
# Dataset variables:
# 'title', 'popularity', 'release_year', 'vote_average', 'type', 'primary_genre'

# %%
titles = neetflix_titles_raw['title'].head(600)
results = []
print("Starting API data collection...")

for title in titles:
    try:
        url = f"https://api.themoviedb.org/3/search/movie?api_key={api_key}&query={title}"
        response = requests.get(url)
        
        # Check if request was successful
        if response.status_code == 200:
            data = response.json()
            if data['results']:
                # Extract only the 4 variables
                movie = data['results'][0]
                results.append({
                    'title': title,
                    'popularity': movie.get('popularity'),
                    'release_year': movie.get('release_date', '0000')[:4],
                    'vote_average': movie.get('vote_average')
                })
        
        # RATE LIMIT: Pause for 0.25 seconds (4 requests per second)
        time.sleep(0.25)
        
    except Exception as e:
        print(f"Error fetching {title}: {e}")

# Create the Raw API dataframe
df_tmdb_raw = pd.DataFrame(results)
# Out:
# Starting API data collection...

# %% [markdown]
# ## 2. Assess data
#
# Assess the data according to data quality and tidiness metrics using the report below.
#
# List **two** data quality issues and **two** tidiness issues. Assess each data issue visually **and** programmatically, then briefly describe the issue you find.  **Make sure you include justifications for the methods you use for the assessment.**

# %% [markdown]
# ### Quality Issue 1: Missing Values (Completeness)

# %%
#FILL IN - Inspecting the dataframe visually
# Scroll through the dataframe to see NaN entries
neetflix_titles_raw.tail(10)
# Out:
#      show_id     type               title                 director  \
# 8797   s8798  TV Show           Zak Storm                      NaN
# 8798   s8799    Movie            Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800    Movie               Zenda           Avadhoot Gupte
# 8800   s8801  TV Show  Zindagi Gulzar Hai                      NaN
# 8801   s8802    Movie             Zinzana          Majid Al Ansari
# 8802   s8803    Movie              Zodiac            David Fincher
# 8803   s8804  TV Show         Zombie Dumb                      NaN
# 8804   s8805    Movie          Zombieland          Ruben Fleischer
# 8805   s8806    Movie                Zoom             Peter Hewitt
# 8806   s8807    Movie              Zubaan              Mozez Singh
#
#                                                    cast  \
# 8797  Michael Johnston, Jessica Gee-George, Christin...
# 8798  Adil Hussain, Mona Singh, K.K. Raina, Sanjay M...
# 8799  Santosh Juvekar, Siddharth Chandekar, Sachit P...
# ...

# %%
#FILL IN - Inspecting the dataframe programmatically
# Count nulls per column
neetflix_titles_raw.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# Issue: Several columns in the merged dataset contain NaN or null values, particularly in the vote_average and popularity columns.
#
# Justification: For a measurable relationship analysis, missing numerical data will lead to skewed results or errors during plotting.

# %% [markdown]
# ### Quality Issue 2: Inconsistent Country/Rating Formats (Consistency)

# %%
# Look at the 'country' column for entries with commas
neetflix_titles_raw['country'].head(20)
# Out:
# 0                                         United States
# 1                                          South Africa
# 2                                                   NaN
# 3                                                   NaN
# 4                                                 India
# 5                                                   NaN
# 6                                                   NaN
# 7     United States, Ghana, Burkina Faso, United Kin...
# 8                                        United Kingdom
# 9                                         United States
# 10                                                  NaN
# 11                                                  NaN
# 12                              Germany, Czech Republic
# 13                                                  NaN
# 14                                                  NaN
# 15                                        United States
# 16                                                  NaN
# ...

# %%
neetflix_titles_raw['country'].value_counts()
# Out:
# country
# United States                                    2818
# India                                             972
# United Kingdom                                    419
# Japan                                             245
# South Korea                                       199
#                                                  ...
# Russia, Spain                                       1
# Croatia, Slovenia, Serbia, Montenegro               1
# Japan, Canada                                       1
# United States, France, South Korea, Indonesia       1
# United Arab Emirates, Jordan                        1
# Name: count, Length: 748, dtype: int64

# %% [markdown]
# Issue: The country and rating columns often contain multiple values (e.g., "United States, India, South Korea") or inconsistent labels.
#
# Justification: Having multiple countries in one string prevents accurate grouping or filtering by region.

# %% [markdown]
# ### Tidiness Issue 1: The listed_in column contains multiple genres in one cell.

# %%
print(neetflix_titles_raw['listed_in'].head())
# Out:
# 0                                        Documentaries
# 1      International TV Shows, TV Dramas, TV Mysteries
# 2    Crime TV Shows, International TV Shows, TV Act...
# 3                               Docuseries, Reality TV
# 4    International TV Shows, Romantic TV Shows, TV ...
# Name: listed_in, dtype: object

# %%
neetflix_titles_raw['listed_in'].str.contains(',')
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 8802     True
# 8803     True
# 8804     True
# 8805     True
# 8806     True
# Name: listed_in, Length: 8807, dtype: bool

# %% [markdown]
# Issue and justification: The listed_in column contains multiple genres (e.g., "Comedies, Dramas, Romantic Movies"), violating tidy data principles — one variable per column

# %% [markdown]
# ### Tidiness Issue 2: Type Column Could Be Categorical

# %%
neetflix_titles_raw['type'].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %%
neetflix_titles_raw['type'].dtype
# Out:
# dtype('O')

# %% [markdown]
# Issue and justification: type (“Movie” or “TV Show”) is a categorical variable, not string — converting improves clarity and memory use.

# %% [markdown]
# ## 3. Clean data
# Clean the data to solve the 4 issues corresponding to data quality and tidiness found in the assessing step. **Make sure you include justifications for your cleaning decisions.**
#
# After the cleaning for each issue, please use **either** the visually or programatical method to validate the cleaning was succesful.
#
# At this stage, you are also expected to remove variables that are unnecessary for your analysis and combine your datasets. Depending on your datasets, you may choose to perform variable combination and elimination before or after the cleaning stage. Your dataset must have **at least** 4 variables after combining the data.

# %%
#making copies
netflix = neetflix_titles_raw.copy()
tmdb = df_tmdb_raw.copy()

# %% [markdown]
# ### **Quality Issue 1: Handling Missing Values (Data Quality)**

# %%
# Drop rows missing 'title' or 'type' (essential info)
netflix = netflix.dropna(subset=['title', 'type'])

# Fill missing 'country' with 'Unknown'
netflix['country'] = netflix['country'].fillna('Unknown')

# %%
#validating
netflix.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country            0
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# Justification: Keeping incomplete but relevant rows prevents losing too much data, while replacing NaN with “Unknown” maintains dataset integrity.

# %% [markdown]
# ### **Quality Issue 2: Inconsistent Country/Rating Formats (Consistency)**

# %%
#cleaning
netflix['country'] = netflix['country'].str.strip().str.title()
netflix['rating'] = netflix['rating'].str.upper().str.replace(' ', '')

# %%
#validating
netflix['country'].value_counts().head()
# Out:
# country
# United States     2818
# India              972
# Unknown            831
# United Kingdom     419
# Japan              245
# Name: count, dtype: int64

# %% [markdown]
# Justification: Standardizing text ensures that the same category (e.g., “United States”) isn’t treated as multiple unique values.

# %% [markdown]
# ### **Tidiness Issue 1: Split Multiple Genres into Separate Rows**

# %%
netflix = netflix.assign(listed_in=netflix['listed_in'].str.split(', '))
netflix = netflix.explode('listed_in').reset_index(drop=True)

# %%
#validating
print(netflix['listed_in'].head(10))
# Out:
# 0             Documentaries
# 1    International TV Shows
# 2                 TV Dramas
# 3              TV Mysteries
# 4            Crime TV Shows
# 5    International TV Shows
# 6     TV Action & Adventure
# 7                Docuseries
# 8                Reality TV
# 9    International TV Shows
# Name: listed_in, dtype: object

# %% [markdown]
# Justification: Each row should represent one observation (movie–genre pair). This structure allows clearer analysis by genre.

# %% [markdown]
# ### **Tidiness Issue 2: Convert 'type' to Categorical**

# %%
netflix['type'] = netflix['type'].astype('category')

# %%
#validating
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19323 entries, 0 to 19322
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       19323 non-null  object
#  1   type          19323 non-null  category
#  2   title         19323 non-null  object
#  3   director      13439 non-null  object
#  4   cast          17819 non-null  object
#  5   country       19323 non-null  object
#  6   date_added    19303 non-null  object
#  7   release_year  19323 non-null  int64
#  8   rating        19317 non-null  object
#  9   duration      19320 non-null  object
#  10  listed_in     19323 non-null  object
#  11  description   19323 non-null  object
# dtypes: category(1), int64(1), object(10)
# memory usage: 1.6+ MB

# %% [markdown]
# Justification: Categorical variables improve readability and performance for analysis and modeling.

# %% [markdown]
# ### **Remove unnecessary variables and combine datasets**

# %%
netflix = netflix[['title', 'release_year', 'country', 'listed_in']]
tmdb = tmdb[['title', 'vote_average', 'popularity']]
netflix['title_clean'] = netflix['title'].str.lower().str.strip()
tmdb['title_clean'] = tmdb['title'].str.lower().str.strip()
combined = pd.merge(
    netflix,
    tmdb,
    on='title_clean',
    how='inner',
    suffixes=('_netflix', '_tmdb')
)
combined = combined.drop(columns=['title_tmdb'])
combined = combined.rename(columns={'title_netflix': 'title'})

# %%
combined = combined.drop_duplicates(subset=['title'], keep='first')

# %%
combined.shape
combined.head(67)
# Out:
#                                         title  release_year        country  \
# 0                        Dick Johnson Is Dead          2020  United States
# 1                               Blood & Water          2021   South Africa
# 4                                   Ganglands          2021        Unknown
# 7                               Midnight Mass          2021        Unknown
# 10           My Little Pony: A New Generation          2021        Unknown
# ..                                        ...           ...            ...
# 141                                   Lucifer          2021  United States
# 144                      Omo Ghetto: the Saga          2020        Nigeria
# 147                                      Prey          2021        Unknown
# 149  Blood Brothers: Malcolm X & Muhammad Ali          2021        Unknown
# 151                               Mighty Raju          2017        Unknown
#
# ...

# %% [markdown]
# ## 4. Update your data store
# Update your local database/data store with the cleaned data, following best practices for storing your cleaned data:
#
# - Must maintain different instances / versions of data (raw and cleaned data)
# - Must name the dataset files informatively
# - Ensure both the raw and cleaned data is saved to your database/data store

# %%
import os

# Create folders for raw and cleaned data
os.makedirs("data/raw", exist_ok=True)
os.makedirs("data/cleaned", exist_ok=True)

# %%
#raw
neetflix_titles_raw.to_csv("data/raw/netflix_titles_raw.csv",index=False)
df_tmdb_raw.to_csv("data/raw/tmdb_movies_raw.csv",index=False)
#cleaned
netflix.to_csv("data/cleaned/netflix_titles_cleaned.csv",index=False)
tmdb.to_csv("data/cleaned/tmdb_movies_cleaned.csv",index=False)
combined.to_csv("data/cleaned/netflix_tmdb_merged_cleaned.csv",index=False)

# %% [markdown]
# ## 5. Answer the research question
#
# ### **5.1:** Define and answer the research question

# %% [markdown]
# *Research question:* Which movie genres on Netflix tend to have higher TMDB ratings, and how does popularity relate to these ratings?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# For plotting style
sns.set(style="whitegrid")

# Group by genre and calculate mean rating and popularity
genre_stats = combined.groupby('listed_in').agg({
    'vote_average': 'mean',
    'popularity': 'mean'
}).sort_values('vote_average', ascending=False).reset_index()

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=genre_stats, x='vote_average', y='listed_in', palette='viridis')
plt.title("Average TMDB Rating by Genre for Netflix Movies")
plt.xlabel("Average Rating")
plt.ylabel("Genre")
plt.show()

# %% [markdown]
# *Answer to research question:* classic movies have the best quality according to TMDB users

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(data=combined, x='popularity', y='vote_average', hue='listed_in', alpha=0.7)
plt.title("TMDB Popularity vs Rating for Netflix Movies by Genre")
plt.xlabel("Popularity")
plt.ylabel("Rating")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# *Answer to research question:*
# Movies with ratings between 6 and 8 but low popularity (0–5) indicate that moderately well-rated films on Netflix may not attract broad viewership or social attention. This suggests a disconnect between quality and popularity, highlighting the presence of lesser-known “hidden gems” in the catalog.

# %% [markdown]
# ### **5.2:** Reflection
# In 2-4 sentences, if you had more time to complete the project, what actions would you take? For example, which data quality and structural issues would you look into further, and what research questions would you further explore?

# %% [markdown]
# *Answer:* If I had more time, I would further investigate data quality issues such as missing director and cast information, and standardize country names more thoroughly to improve consistency. I would also explore structural tidiness by analyzing movies with multiple genres in greater depth, possibly creating a multi-label genre model. On the research side, I would examine the relationship between Netflix Originals versus licensed content in terms of ratings, popularity, and revenue, and explore temporal trends in viewership and ratings over the years. This would allow for deeper insights into Netflix’s content strategy and audience preferences.

# %%
import os
os.makedirs("data/cleaned", exist_ok=True)

# %%
combined.to_csv("data/cleaned/netflix_tmdb_merged_cleaned.csv", index=False)

# %%
import os
os.listdir("data/cleaned")
# Out:
# ['netflix_titles_cleaned.csv',
#  'netflix_tmdb_merged_cleaned.csv',
#  'tmdb_movies_cleaned.csv']
